# %%
import pandas as pd
df = pd.read_csv("engine1_FD001.csv")
print(df.columns)
# Out:
# Index(['cycle', 'setting_1', 'setting_2', 'setting_3', 'sensor_1', 'sensor_2',
#        'sensor_3', 'sensor_4', 'sensor_5', 'sensor_6', 'sensor_7', 'sensor_8',
#        'sensor_9', 'sensor_10', 'sensor_11', 'sensor_12', 'sensor_13',
#        'sensor_14', 'sensor_15', 'sensor_16', 'sensor_17', 'sensor_18',
#        'sensor_19', 'sensor_20', 'sensor_21', 'dataset_id'],
#       dtype='object')

# %%
df.head()
# Out:
#    cycle  setting_1  setting_2  setting_3  sensor_1  sensor_2  sensor_3  \
# 0      1    -0.0007    -0.0004      100.0    518.67    641.82   1589.70
# 1      2     0.0019    -0.0003      100.0    518.67    642.15   1591.82
# 2      3    -0.0043     0.0003      100.0    518.67    642.35   1587.99
# 3      4     0.0007     0.0000      100.0    518.67    642.35   1582.79
# 4      5    -0.0019    -0.0002      100.0    518.67    642.37   1582.85
#
#    sensor_4  sensor_5  sensor_6  ...  sensor_13  sensor_14  sensor_15  \
# 0   1400.60     14.62     21.61  ...    2388.02    8138.62     8.4195
# 1   1403.14     14.62     21.61  ...    2388.07    8131.49     8.4318
# 2   1404.20     14.62     21.61  ...    2388.03    8133.23     8.4178
# 3   1401.87     14.62     21.61  ...    2388.08    8133.83     8.3682
# 4   1406.22     14.62     21.61  ...    2388.04    8133.80     8.4294
#
#    sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  sensor_21  \
# ...
